# %%
import gensim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from gensim import corpora
import pyLDAvis
import pyLDAvis.gensim_models
from gensim.models import CoherenceModel

# %% [markdown]
# ## Download data

# %% [markdown]
# Groups full data

# %%
groups_df = pd.read_csv('data/groups.csv', low_memory=False)
groups_df = groups_df.drop(columns=['Unnamed: 0', 'name', 'status', 'description', 'activity', 'members_count'])

# %%
groups_df
# Out:
#            user_id   group_id
# 0              145   34168005
# 1              145   34483558
# 2              145   63133420
# 3              145   62524274
# 4              145     212382
# ...            ...        ...
# 6749302  638374890  301419447
# 6749303  638438887   29425083
# 6749304  638438887   25882042
# 6749305  638438887  122152852
# 6749306        NaN        NaN
#
# [6749307 rows x 2 columns]

# %% [markdown]
# Groups texts with nouns only

# %%
processed_groups = pd.read_csv('data/processed/bspb_groups_nouns.csv')
processed_groups['clear_texts'] = processed_groups['nouns_name'] + ' ' + processed_groups['nouns_description']

# Remove NaN values
processed_groups = processed_groups.loc[processed_groups['clear_texts'].notna()]

# %%
processed_groups
# Out:
#         Unnamed: 0         id  \
# 0                0          1
# 1                1  113246211
# 2                2  180355074
# 9                9  192937987
# 11              11         14
# ...            ...        ...
# 912471      912471   64449308
# 912476      912476  104857566
# 912480      912480   83908177
# 912485      912485   54525929
# 912491      912491   92253912
#
#                                                     name  \
# 0                                          ВКонтакте API
# 1       Сайт, видеомонтаж, портфолио для учителей, восп.
# 2       Орешкин лес.Украшения из дерева от Александрины.
# 9                                      Гринвэй Кронштадт
# 11                                          Дом Культуры
# ...                                                  ...
# 912471    Музейный центр Ваприикки | Тампере | Финляндия
# 912476  ПРОДАЖА,ПОКУПКА и ОБМЕН АВТОМОБИЛЕЙ .(AUTOHOUSE)
# 912480                                  Продукты с фермы
# 912485         Байконур | Новости  | Объявления - 94info
# 912491           Сауна Баня Гостиница "Нептун" г. Лысьва
#
#                                                    status  \
# 0                  Платформа для разработчиков приложений
# 1       Заказ ПОРТФОЛИО, видеопоздравлений, видеопрезе...
# 2       Привет.\tМеня зовут Александрина .Я создаю укр...
# 9                                                     NaN
# 11                                           Дом культуры
# ...                                                   ...
# 912471  Музей | Сайт музея на русском языке: www.vapri...
# 912476                               Тел. 8-953-231-48-00
# 912480                                Фермерские продукты
# 912485            Все объявления Байконура в одном месте!
# 912491  Приходите к нам на экскурсию и мы расскажем Ва...
#
#                                               description  \
# 0       Группа посвящена разработке приложений на осно...
# 1       Выполняю работы по созданию сайтов, портфолио,...
# 2       Жители этого леса - украшения ,они рассказываю...
# 9       ☘️ GreenWay - это уникальные и доступные ЭКО -...
# 11      Анонсы культурных событий Петербурга (и немнож...
# ...                                                   ...
# 912471  Музейный центр Ваприикки в центре города Тампе...
# 912476  - Оформление, договора купли-продажи в любое в...
# 912480  Натуральные продукты с фермы\n\nМы обеспечивае...
# 912485  Для размещения объявления в группе нажимаем ''...
# 912491  "ЛУЧШИЙ БАННЫЙ КОМПЛЕКС" - статус, который при...
#
#                            activity  members_count  \
# 0                        Open group       383414.0
# 1                    Other services          225.0
# 2                            Artist         1929.0
# 9                Household Products          105.0
# 11                 Community Center         5991.0
# ...                             ...            ...
# 912471  Museum, gallery, exhibition          183.0
# 912476                    Transport          135.0
# 912480               Internet store          847.0
# 912485               City community        47036.0
# 912491                        Sauna         3672.0
#
#                                         clear_name  \
# 0                                    вконтакте api
# 1         сайт видеомонтаж портфолио учитель воспа
# 2        орешкин лес украшение дерево александрина
# 9                                гринвэй кронштадт
# 11                                    дом культура
# ...                                            ...
# 912471  музейный центр ваприикки тампере финляндия
# 912476  продажа покупка обмен автомобиль autohouse
# 912480                               продукт ферма
# 912485                 байконур новость объявление
# 912491        сауна баня гостиница нептун г лысьва
#
#                                         clear_description  \
# 0       группа посвящать разработка приложение основа ...
# 1       выполнять работа создание сайт портфолио видео...
# 2       житель лес украшение рассказывать история леге...
# 9       __u2618__ greenway это уникальный доступный эк...
# 11      анонс культурный событие петербург немножко мо...
# ...                                                   ...
# 912471  музейный центр ваприикки центр город тампере п...
# 912476  оформление договор купля продажа любой время п...
# 912480  натуральный продукт ферма обеспечивать свой кл...
# 912485  размещение объявление группа нажимать __u0001f...
# 912491  хороший банный комплекс статус который присваи...
#
#                                        nouns_name  \
# 0                                       вконтакте
# 1        сайт видеомонтаж портфолио учитель воспа
# 2       орешкин лес украшение дерево александрина
# 9                               гринвэй кронштадт
# 11                                   дом культура
# ...                                           ...
# 912471          центр ваприикки тампере финляндия
# 912476           продажа покупка обмен автомобиль
# 912480                              продукт ферма
# 912485                байконур новость объявление
# 912491       сауна баня гостиница нептун г лысьва
#
#                                         nouns_description  \
# 0       группа разработка приложение основа платформа ...
# 1       работа создание сайт портфолио видеоролик виде...
# 2       житель лес украшение история легенда любовь те...
# 9       эко продукт жизнь помощь нанотехнология чистот...
# 11                         анонс событие петербург москва
# ...                                                   ...
# 912471  центр ваприикки центр город тампере семья биле...
# 912476  оформление договор купля продажа время продажа...
# 912480  продукт ферма клиент продукция сыр сулугуни сы...
# 912485  размещение объявление группа запись правило ре...
# 912491  комплекс статус клиент заведение услуга аренда...
#
#                                               clear_texts
# 0       вконтакте группа разработка приложение основа ...
# 1       сайт видеомонтаж портфолио учитель воспа работ...
# 2       орешкин лес украшение дерево александрина жите...
# 9       гринвэй кронштадт эко продукт жизнь помощь нан...
# 11            дом культура анонс событие петербург москва
# ...                                                   ...
# 912471  центр ваприикки тампере финляндия центр ваприи...
# 912476  продажа покупка обмен автомобиль оформление до...
# 912480  продукт ферма продукт ферма клиент продукция с...
# 912485  байконур новость объявление размещение объявле...
# 912491  сауна баня гостиница нептун г лысьва комплекс ...
#
# [436196 rows x 12 columns]

# %% [markdown]
# Posts and reposts

# %%
processed_reposts = pd.read_csv('data/processed/bspb_reposts_nouns.csv')
processed_posts = pd.read_csv('data/processed/bspb_posts_nouns.csv')

# Remove NaN values
processed_reposts = processed_reposts.loc[processed_reposts['nouns'].notna()]
processed_posts = processed_posts.loc[processed_posts['nouns'].notna()]

# %%
processed_reposts
# Out:
#       Unnamed: 0   owner_id  post_id  \
# 0              0  273694109      826
# 1              1  116524602    10482
# 2              2   15835662     1127
# 3              3   31868444     6676
# 4              4   31868444     6673
# ...          ...        ...      ...
# 6390        6390     554424     5189
# 6393        6393    1824199     3202
# 6394        6394  267284787      396
# 6395        6395   17665225     1333
# 6396        6396  170074292     6597
#
#                                                    text  \
# 0     РОССИЯ: ОСТАНОВИТЬ ЗАКОНОПРОЕКТ О ПРИНУДИТЕЛЬН...
# 1     Спиcoк caмых эффeктивных лeкaрcтв нa рaзныe cл...
# 2     Кому меда? еще остался, прямиком из Тайги.\nЗа...
# 3     22 МАЯ | 20:00\nТанцевальный спектакль «плач/ь...
# 4     Сегодня день рождения [id31868444|Даши], нашег...
# ...                                                 ...
# 6390                           Давайте спасать планету!
# 6393  Подарочный сертификат🏃‍🏃‍🏃‍\n\n22 декабря – ка...
# 6394                                      Учись студент
# 6395                            Беда не приходит одна 😆
# 6396        В сериале актеры тоже будут в масках 🔥🤦🏻‍♀️
#
#                                              clear_text  \
# 0     россия останавливать законопроект принудительн...
# 1     список самый эффективный лекарство разный случ...
# 2     мед оставаться прямиком тайга качество ручатьс...
# 3     май танцевальный спектакль плач ь билет dancek...
# 4     сегодня день рождение даша наш фитнес тренер д...
# ...                                                 ...
# 6390                             давать спасать планета
# 6393  подарочный сертификат __u0001f3c3__ __u0001f3c...
# 6394                                    учиться студент
# 6395                       беда приходить __u0001f606__
# 6396  сериал актер маска __u0001f525__ __u0001f926__...
#
#                                                   nouns
# 0     россия законопроект вакцинация ноябрь гос дума...
# 1                         список лекарство случай жизнь
# 2                              мед тайга качество личка
# 3     май спектакль плач билет счастие счастие свобо...
# 4     день рождение даша фитнес тренер растяжка утро...
# ...                                                 ...
# 6390                                            планета
# 6393  сертификат декабрь катастрофа город сувенир па...
# 6394                                            студент
# 6395                                               беда
# 6396                                 сериал актер маска
#
# [6057 rows x 6 columns]

# %%
processed_posts
# Out:
#         Unnamed: 0    from_id  post_id  \
# 1                1        145     2292
# 2                2        145     2292
# 3                3        145     2290
# 4                4        145     2290
# 5                5        145     2290
# ...            ...        ...      ...
# 810835      810835  619951213       49
# 810836      810836  619951213       47
# 810837      810837  619951213       35
# 810838      810838  620178523      449
# 810839      810839  620282877        5
#
#                                                      text  \
# 1       Сколько же всего изменилось за это время, 7 ле...
# 2       Жаль, что из-за политики Абрамовича клуб так и...
# 3       Полтора года назад искал решение некоторых сво...
# 4       На данный момент дружим семьями и безумно благ...
# 5       К сожалению не имею возможности поздравить лич...
# ...                                                   ...
# 810835                она вместит себе в глотку револьвер
# 810836                                      огонь да мясо
# 810837                                       Твой аромат.
# 810838                  Вводи код 6s2jq8 и получай 5 руб!
# 810839  Добрый день, рада знакомству с новыми подписчи...
#
#                                                clear_text  \
# 1       сколько изменяться время год проходить рождать...
# 2       жаль политика абрамович клуб начинать играть с...
# 3       полтора год назад искать решение некоторый сво...
# 4       данный момент дружить семья безумно благодарны...
# 5       сожаление иметь возможность поздравлять лично ...
# ...                                                   ...
# 810835                           вмещать глотка револьвер
# 810836                                         огонь мясо
# 810837                                        твой аромат
# 810838                           вводить код получать руб
# 810839  добрый день рад знакомство новый подписчик тем...
#
#                                                     nouns
# 1       время год сын бизнес вещь челси сердце клуб иг...
# 2             политика абрамович клуб надежда челси слава
# 3       год решение проблема простор интернет виктор п...
# 4                             момент семья судьба человек
# 5           сожаление возможность год жизнь ребенок успех
# ...                                                   ...
# 810835                                   глотка револьвер
# 810836                                         огонь мясо
# 810837                                             аромат
# 810838                                            код руб
# 810839                день знакомство подписчик тема блог
#
# [565698 rows x 6 columns]

# %% [markdown]
# ## Analyze users

# %%
lda_model_groups = gensim.models.ldamodel.LdaModel.load('models/lda_model_groups_notna_13.model')
lda_model_posts_reposts = gensim.models.ldamodel.LdaModel.load('models/lda_model_posts_reposts_nouns_notna_12.model')

# %%
# An auxiliary function for getting corpus from DF
def get_corpus(series):
    texts_list = [str(values).split() for values in series]
    id2word = corpora.Dictionary(texts_list)
    corpus = [id2word.doc2bow(text) for text in texts_list]
    return corpus

# %%
# Function for getting vectors of user's activities and opinions (posts and reposts) and interests (groups)
def analyze_user(user_id):
    
    user_posts = processed_posts.loc[processed_posts['from_id'] == int(user_id)]
    user_reposts = processed_reposts.loc[processed_reposts['owner_id'] == int(user_id)]
    user_posts_reposts = pd.concat([user_posts['nouns'], user_reposts['nouns']])
    if len(user_posts_reposts) > 0:
        posts_reposts_corpus = get_corpus(user_posts_reposts)
        lda_model_activities = lda_model_posts_reposts
        posts_reposts_topics = lda_model_activities[posts_reposts_corpus]
        posts_reposts_topics = posts_reposts_topics[0]
        
    else:
        posts_reposts_topics = [(0, None),
                                (1, None),
                                (2, None),
                                (3, None),
                                (4, None),
                                (5, None),
                                (6, None),
                                (7, None),
                                (8, None),
                                (9, None),
                                (10, None),
                                (11, None)]
    
    user_groups_list = list(groups_df.loc[groups_df['user_id'] == str(user_id)]['group_id'].values)
    user_groups_list = [int(group) for group in user_groups_list]
    user_groups = processed_groups.loc[processed_groups['id'].isin(user_groups_list)]
    if len(user_groups) > 0:    
        groups_corpus = get_corpus(user_groups['clear_texts'])
        lda_model_interests = lda_model_groups
        groups_topics = lda_model_interests[groups_corpus]
        groups_topics = groups_topics[0]
    else:
        groups_topics = [(0, None),
                                (1, None),
                                (2, None),
                                (3, None),
                                (4, None),
                                (5, None),
                                (6, None),
                                (7, None),
                                (8, None),
                                (9, None),
                                (10, None),
                                (11, None),
                                (12, None)]
    return posts_reposts_topics, groups_topics

# %%
analyze_user(17039363)[1][0]
# Out:
# [(0, 0.020074721),
#  (1, 0.019182287),
#  (2, 0.30670038),
#  (4, 0.5829292),
#  (9, 0.018949088),
#  (12, 0.036696296)]

# %% [markdown]
# ### Collect set of users

# %%
users_with_posts = set(processed_posts['from_id'])

# Convert ids into int
users_with_posts = [int(user_id) for user_id in users_with_posts]
len(users_with_posts)
# Out:
# 12546

# %%
users_with_reposts = set(processed_reposts['owner_id'])

# Convert ids into int
users_with_reposts = [int(user_id) for user_id in users_with_reposts]
len(users_with_reposts)
# Out:
# 2580

# %%
users_with_groups = set(groups_df['user_id'])
users_with_groups = list(users_with_groups)

# Remove nan
users_with_groups = users_with_groups[1:]
# Remove user_id
user_id_ind = users_with_groups.index('user_id')
users_with_groups.pop(10228)

# Convert ids into int
users_with_groups = [int(user_id) for user_id in users_with_groups]
len(users_with_groups)
# Out:
# 28970

# %% [markdown]
# Final set of users

# %%
users = (set(users_with_posts).union(set(users_with_reposts))).union(set(users_with_groups))
len(users)
# Out:
# 28997

# %%
topics_posts_reposts = []
topics_groups = []

# %%
for u in users:  
    t_posts_reposts, t_groups = analyze_user(u)
    topics_posts_reposts.append(t_posts_reposts)
    topics_groups.append(t_groups)

# %%
POSTS_REPOSTS_MODEL_TOPICS_NUM = 12
GROUPS_MODEL_TOPICS_NUM = 13

# %%
final_df = pd.DataFrame()
final_df['user_id'] = users

for topic_n in range(POSTS_REPOSTS_MODEL_TOPICS_NUM):
    tops_n = []
    for topic in topics_posts_reposts:
        flag = False
        
        if len(topic) != POSTS_REPOSTS_MODEL_TOPICS_NUM:
            topic = topic[0]
        for item in topic:
            if item[0] == topic_n:
                tops_n.append(item[1])
                flag = True
        
        if not flag:
            tops_n.append(None)

    final_df[f'posts_reposts_{topic_n}'] = tops_n

for topic_n in range(GROUPS_MODEL_TOPICS_NUM):
    tops_n = []
    for topic in topics_groups:
        flag = False
        
        if len(topic) != GROUPS_MODEL_TOPICS_NUM:
            topic = topic[0]
        for item in topic:
            if item[0] == topic_n:
                tops_n.append(item[1])
                flag = True
        
        if not flag:
            tops_n.append(None)

    final_df[f'groups_{topic_n}'] = tops_n

# %%
final_df
# Out:
#          user_id  posts_reposts_0  posts_reposts_1  posts_reposts_2  \
# 0       17489295         0.053998         0.040320         0.061113
# 1          91020         0.058680         0.043816         0.066413
# 2       17039363         0.064255         0.047979         0.072723
# 3        2430764         0.064255         0.047979         0.072723
# 4       76546053         0.064255         0.047979         0.072723
# ...          ...              ...              ...              ...
# 41631  177864684         0.053998         0.040320         0.061113
# 41632   18117179         0.064255         0.047979         0.072723
# 41633   24248311         0.064255         0.047979         0.072723
# 41634    1216919         0.064255         0.047979         0.072723
# 41635  248488660              NaN              NaN              NaN
#
#        posts_reposts_3  posts_reposts_4  posts_reposts_5  posts_reposts_6  \
# 0             0.062024         0.053151         0.067862         0.314564
# 1             0.067403         0.057760         0.073747         0.255121
# 2             0.073806         0.063248         0.080753         0.184357
# 3             0.073806         0.063248         0.080753         0.184357
# 4             0.073806         0.063248         0.080753         0.184357
# ...                ...              ...              ...              ...
# 41631         0.062024         0.053151         0.067862         0.314564
# 41632         0.073806         0.063248         0.080753         0.184357
# 41633         0.073806         0.063248         0.080753         0.184357
# 41634         0.073806         0.063248         0.080753         0.184357
# 41635              NaN              NaN              NaN              NaN
#
#        posts_reposts_7  posts_reposts_8  ...  groups_3  groups_4  groups_5  \
# 0             0.059733         0.077446  ...       NaN  0.456763       NaN
# 1             0.064913         0.084162  ...       NaN  0.629385       NaN
# 2             0.071080         0.092158  ...       NaN  0.581425       NaN
# 3             0.071080         0.092158  ...       NaN  0.647599       NaN
# 4             0.071080         0.092158  ...  0.064162  0.354159       NaN
# ...                ...              ...  ...       ...       ...       ...
# 41631         0.059733         0.077446  ...  0.014069  0.296296  0.012418
# 41632         0.071080         0.092158  ...  0.020940  0.029172  0.018496
# 41633         0.071080         0.092158  ...       NaN  0.647638       NaN
# 41634         0.071080         0.092158  ...       NaN  0.662201       NaN
# 41635              NaN              NaN  ...       NaN  0.265030       NaN
#
#        groups_6  groups_7  groups_8  groups_9  groups_10  groups_11  groups_12
# 0           NaN       NaN  0.017124       NaN        NaN        NaN        NaN
# 1           NaN       NaN       NaN  0.041771        NaN        NaN        NaN
# 2           NaN       NaN       NaN  0.018878        NaN        NaN   0.038319
# 3           NaN       NaN  0.011934       NaN        NaN        NaN        NaN
# 4           NaN       NaN       NaN  0.049147        NaN        NaN   0.058909
# ...         ...       ...       ...       ...        ...        ...        ...
# 41631  0.013902  0.013982  0.030362  0.017184        NaN   0.017058   0.016408
# 41632  0.020703  0.020822  0.044191  0.025595   0.014819   0.025332   0.024431
# 41633       NaN       NaN  0.011934       NaN        NaN        NaN        NaN
# 41634       NaN       NaN  0.012472       NaN        NaN        NaN        NaN
# 41635       NaN       NaN       NaN  0.033708        NaN        NaN        NaN
#
# [41636 rows x 26 columns]

# %%
final_df.to_csv('users_activities_groups.csv')
